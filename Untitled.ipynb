# %%
from __future__ import division, unicode_literals, print_function  # for compatibility with Python 2 and 3

import matplotlib as mpl
import matplotlib.pyplot as plt

# change the following to %matplotlib notebook for interactive plotting
# %matplotlib inline

# Optionally, tweak styles.
mpl.rc('figure',  figsize=(10, 5))
mpl.rc('image', cmap='gray')

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series  # for convenience

import pims
import trackpy as tp

# %%
@pims.pipeline
def gray(image):
    return image[:, :,0]  # Take just the green channel

frames = pims.open('200Frames.tif')

# %%
frames[0]
# Out:
# Frame([[ 28,  35,  52, ...,  30,  35,  44],
#        [ 39,  50,  62, ...,  32,  44,  52],
#        [ 46,  62,  71, ...,  36,  45,  56],
#        ...,
#        [ 48,  86, 123, ...,  65,  77,  84],
#        [ 41,  87, 131, ...,  25,  26,  27],
#        [ 36,  77, 121, ...,  12,  13,  14]], dtype=uint8)

# %%
f = tp.locate(frames[0], 11, separation = 7)

# %%
# %matplotlib notebook
tp.annotate(f, frames[0]);
# Out:
# <img src="data:image/png;base64,..." width="432">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-f3863362b7e9> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'notebook')
# ----> 2 tp.annotate(f, frames[0], markersize=1);
#
# ~/.local/lib/python3.8/site-packages/trackpy/plots.py in wrapper(*args, **kwargs)
#      51         legend = kwargs.pop('legend', False)
#      52
# ---> 53         result = func(*args, **kwargs)
#      54
#      55         if legend:
#
# TypeError: annotate() got an unexpected keyword argument 'markersize'
